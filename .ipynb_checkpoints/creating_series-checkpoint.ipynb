# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

from statsmodels.tsa.api import Holt

import plotly.graph_objs as go
from plotly.offline import iplot

# %%
data1 = pd.read_csv('data2/daily-minimum-temperatures-in-me.csv')
data1 = data1.iloc[:397, :]

# %%
data1
# Out:
#           Date Daily minimum temperatures
# 0     1/1/1981                       20.7
# 1     1/2/1981                       17.9
# 2     1/3/1981                       18.8
# 3     1/4/1981                       14.6
# 4     1/5/1981                       15.8
# ..         ...                        ...
# 392  1/28/1982                       12.5
# 393  1/29/1982                         17
# 394  1/30/1982                       17.1
# 395  1/31/1982                         14
# 396   2/1/1982                       14.6
#
# [397 rows x 2 columns]

# %%
trace0 = go.Scatter(
            x = data1['Date'], y = data1['Daily minimum temperatures'], name='Daily minimum temperatures'
            )
    
data = [trace0 ]
layout = {'title': 'Data1'}
    
fig = go.Figure(data=data, layout=layout)
iplot(fig)
# Out:
# <div>                            <div id="208065ab-eaf3-40b8-98f4-98e21c42ee62" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("208065ab-eaf3-40b8-98f4-98e21c42ee62")) {                    Plotly.newPlot(                        "208065ab-eaf3-40b8-98f4-98e21c42ee62",                        [{"name": "Daily minimum temperatures", "type": "scatter", "x": ["1/1/1981", "1/2/1981", "1/3/1981", "1/4/1981", "1/5/1981", "1/6/1981", "1/7/1981", "1/8/1981", "1/9/1981", "1/10/1981", "1/11/1981", "1/12/1981", "1/13/1981", "1/14/1981", "1/15/1981", "1/16/1981", "1/17/1981", "1/18/1981", "1/19/1981", "1/20/1981", "1/21/1981", "1/22/1981", "1/23/1981", "1/24/1981", "1/25/1981", "1/26/1981", "1/27/1981", "1/28/1981", "1/29/1981", "1/30/1981", "1/31/1981", "2/1/1981
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3650 entries, 0 to 3649
# Data columns (total 2 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        3650 non-null   object
#  1   Daily minimum temperatures  3650 non-null   object
# dtypes: object(2)
# memory usage: 57.2+ KB

# %%
data2 = pd.read_csv('data2/Electric_Production.csv')
data2
# Out:
#           DATE  IPG2211A2N
# 0     1/1/1985     72.5052
# 1     2/1/1985     70.6720
# 2     3/1/1985     62.4502
# 3     4/1/1985     57.4714
# 4     5/1/1985     55.3151
# ..         ...         ...
# 392   9/1/2017     98.6154
# 393  10/1/2017     93.6137
# 394  11/1/2017     97.3359
# 395  12/1/2017    114.7212
# 396   1/1/2018    129.4048
#
# [397 rows x 2 columns]

# %%
trace0 = go.Scatter(
            x = data2['DATE'], y = data2['IPG2211A2N'], name='IPG2211A2N'
            )
    
data = [trace0 ]
layout = {'title': 'Data2'}
    
fig = go.Figure(data=data, layout=layout)
iplot(fig)
# Out:
# <div>                            <div id="3023314c-c751-4694-ac85-538c07606c0b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3023314c-c751-4694-ac85-538c07606c0b")) {                    Plotly.newPlot(                        "3023314c-c751-4694-ac85-538c07606c0b",                        [{"name": "IPG2211A2N", "type": "scatter", "x": ["1/1/1985", "2/1/1985", "3/1/1985", "4/1/1985", "5/1/1985", "6/1/1985", "7/1/1985", "8/1/1985", "9/1/1985", "10/1/1985", "11/1/1985", "12/1/1985", "1/1/1986", "2/1/1986", "3/1/1986", "4/1/1986", "5/1/1986", "6/1/1986", "7/1/1986", "8/1/1986", "9/1/1986", "10/1/1986", "11/1/1986", "12/1/1986", "1/1/1987", "2/1/1987", "3/1/1987", "4/1/1987", "5/1/1987", "6/1/1987", "7/1/1987", "8/1/1987", "9/1/1987", "10/1/1987", "11/
# ...

# %%
data3 = pd.read_csv('data2/monthly-beer-production-in-austr.csv')
data3 = data3.iloc[:397, :]
data3
# Out:
#        Month  Monthly beer production
# 0    1956-01                     93.2
# 1    1956-02                     96.0
# 2    1956-03                     95.2
# 3    1956-04                     77.1
# 4    1956-05                     70.9
# ..       ...                      ...
# 392  1988-09                    145.1
# 393  1988-10                    183.7
# 394  1988-11                    210.5
# 395  1988-12                    203.3
# 396  1989-01                    153.3
#
# [397 rows x 2 columns]

# %%
trace0 = go.Scatter(
            x = data3['Month'], y = data3['Monthly beer production'], name='Monthly beer production'
            )
    
data = [trace0 ]
layout = {'title': 'Data3'}
    
fig = go.Figure(data=data, layout=layout)
iplot(fig)
# Out:
# <div>                            <div id="c4d4ea8f-8769-4804-9249-510028789fed" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c4d4ea8f-8769-4804-9249-510028789fed")) {                    Plotly.newPlot(                        "c4d4ea8f-8769-4804-9249-510028789fed",                        [{"name": "Monthly beer production", "type": "scatter", "x": ["1956-01", "1956-02", "1956-03", "1956-04", "1956-05", "1956-06", "1956-07", "1956-08", "1956-09", "1956-10", "1956-11", "1956-12", "1957-01", "1957-02", "1957-03", "1957-04", "1957-05", "1957-06", "1957-07", "1957-08", "1957-09", "1957-10", "1957-11", "1957-12", "1958-01", "1958-02", "1958-03", "1958-04", "1958-05", "1958-06", "1958-07", "1958-08", "1958-09", "1958-10", "1958-11", "1958-12", "1959-01",
# ...

# %%
df_time = data2['DATE']
df_time = pd.to_datetime(df_time)

# %%
final_df = pd.concat([df_time, data1['Daily minimum temperatures'], data2['IPG2211A2N'], data3['Monthly beer production']], axis=1)

# %%
final_df
# Out:
#           DATE Daily minimum temperatures  IPG2211A2N  Monthly beer production
# 0   1985-01-01                       20.7     72.5052                     93.2
# 1   1985-02-01                       17.9     70.6720                     96.0
# 2   1985-03-01                       18.8     62.4502                     95.2
# 3   1985-04-01                       14.6     57.4714                     77.1
# 4   1985-05-01                       15.8     55.3151                     70.9
# ..         ...                        ...         ...                      ...
# 392 2017-09-01                       12.5     98.6154                    145.1
# 393 2017-10-01                         17     93.6137                    183.7
# 394 2017-11-01                       17.1     97.3359                    210.5
# 395 2017-12-01                         14    114.7212                    203.3
# 396 2018-01-01                       14.6    129.4048                    153.3
#
# [397 rows x 4 columns]

# %%
new_cols = ['DATE', 'MIN_TEMPR', 'ELECTRIC_PROD', 'BEER_PROD']
old_cols = final_df.columns
replace_cols = dict(zip(old_cols, new_cols))

# %%
final_df = final_df.rename(columns = replace_cols)

# %%
final_df
# Out:
#           DATE MIN_TEMPR  ELECTRIC_PROD  BEER_PROD
# 0   1985-01-01      20.7        72.5052       93.2
# 1   1985-02-01      17.9        70.6720       96.0
# 2   1985-03-01      18.8        62.4502       95.2
# 3   1985-04-01      14.6        57.4714       77.1
# 4   1985-05-01      15.8        55.3151       70.9
# ..         ...       ...            ...        ...
# 392 2017-09-01      12.5        98.6154      145.1
# 393 2017-10-01        17        93.6137      183.7
# 394 2017-11-01      17.1        97.3359      210.5
# 395 2017-12-01        14       114.7212      203.3
# 396 2018-01-01      14.6       129.4048      153.3
#
# [397 rows x 4 columns]

# %%
final_df.to_csv(r'data\final_data2.csv', index=False)
